# %% [markdown]
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
# <b> Reviewer's comment 3</b>
#
#
# Your project is great and does not have any significant issues that need to be fixed. Therefore, I accept the project now.
#
#
# Here's a nice playlist [Introduction to
# Deep Learning](https://www.youtube.com/playlist?list=PLtBw6njQRU-rwp5__7C0oIVt26ZgjG9NI) on youtube that you may find helpful and interesting. This is another interesting [Computer Vision Playlist](https://www.youtube.com/playlist?list=PLf7L7Kg8_FNxHATtLwDceyh72QQL9pvpQ).
#
#
# I hope you enjoyed this topic. Good luck!
#
# </div>

# %% [markdown]
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
# <b> Reviewer's comment 2</b>
#
#
# Thank you for the updates! Please write a couple of sentences in the introduction.
#
#
# </div>

# %% [markdown]
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
# <b> Reviewer's comment</b>
#
# Hi, Rossi! I am a reviewer on this project.
#
# Before we start, I want to pay your attention to the color marking:
#
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment ✔️</b>
#
# Great solutions and ideas that can and should be used in the future are in green comments.
# </div>
#
#
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment ⚠️</b>
#
# Yellow color indicates what should be optimized. This is not necessary, but it will be great if you make changes to this project.
# </div>
#
#
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment ❌</b>
#
# Issues that need to be corrected to get right results are indicated in red comments. Note that the project cannot be accepted until these issues are resolved.
# </div>
#
# <hr>
#
# **Please, use some color other than those listed to highlight answers to my comments.**
# I would also ask you **not to change, move or delete my comments** so that it would be easier for me to navigate during the next review.
#
# In addition, my comments are defined as headings.
# They can mess up the content, however, they are convenient, since you can immediately go to them. I will remove the headings from my comments in the next review.
#
#
#
# <hr>
#
# <font color='dodgerblue'>**A few words about the project:**</font> thank you very much for submitting the project! You have successfully analyzed data, built a model and recieved significant results, great job!
#
#
# However, in order to fully meet the project criteria, let's add a title and introduction to the project :)
#
#
#
#
# </div>

# %% [markdown]
# # Computer Vision

# %% [markdown]
# ## Introduction

# %% [markdown]
# This project focuses on developing a machine learning model to predict the apparent age of individuals based on their facial images. Using a dataset containing various images of people with labeled ages, the project aims to analyze and understand the age distribution within the dataset, perform data preprocessing, and visualize the data to gain insights. Key steps in the project include exploratory data analysis (EDA) to identify any patterns or issues within the data, such as age imbalances or image quality, followed by preprocessing tasks like image resizing and normalization to ensure the dataset is suitable for training the model.
#
# The visualizations, such as histograms and box plots, help to summarize the distribution of ages and highlight any potential outliers. Additionally, sample images from the dataset are displayed to better understand the data being used for model training. The project incorporates feedback from reviewers to refine the analysis, ensuring a thorough understanding of the data and its implications for the machine learning model's performance. The ultimate goal is to create a robust model capable of accurately predicting the age of individuals based on their facial features.

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>   Reviewer's comment </b>
#
# Although the main purpose of the project is to create a model, we still need such things as introduction and a title. Please, do not forget about them.
#
#
# </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>   Reviewer's comment 2 </b>
#
# Would you wrtie a couple of sentences here?
#
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 3 </h2>
#
# Great! :)
#
# </div>

# %% [markdown]
# ## Initialization

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from PIL import Image

# %% [markdown]
# ## Load Data

# %% [markdown]
# The dataset is stored in the `/datasets/faces/` folder, there you can find
# - The `final_files` folder with 7.6k photos
# - The `labels.csv` file with labels, with two columns: `file_name` and `real_age`
#
# Given the fact that the number of image files is rather high, it is advisable to avoid reading them all at once, which would greatly consume computational resources. We recommend you build a generator with the ImageDataGenerator generator. This method was explained in Chapter 3, Lesson 7 of this course.
#
# The label file can be loaded as an usual CSV file.

# %%
import os

# Define the path to the dataset
dataset_path = '/datasets/faces/'

# List files in the final_files folder
photos_path = os.path.join(dataset_path, 'final_files')
photo_files = os.listdir(photos_path)
print(f"Number of photos: {len(photo_files)}")

# Check the labels.csv file
labels_file_path = os.path.join(dataset_path, 'labels.csv')
print(f"Labels file path: {labels_file_path}")
# Out:
# Number of photos: 7591
# Labels file path: /datasets/faces/labels.csv

# %%
path = '/datasets/faces/'
directory = path + 'final_files/'
labels = pd.read_csv(path + "labels.csv")

# %%
train_datagen = ImageDataGenerator(rescale=1./255)

# %%
train_gen_flow = train_datagen.flow_from_dataframe(
        dataframe= labels,
        directory= directory,
        x_col='file_name',
        y_col='real_age',
        target_size=(224, 224),
        batch_size=32,
        class_mode='raw',
        seed=12345)
# Out:
# Found 7591 validated image filenames.

# %%
image_arrays, age_array = train_gen_flow.next()

# %% [markdown]
# ## EDA

# %%
# labels.info()
labels.head(10)
# Out:
#     file_name  real_age
# 0  000000.jpg         4
# 1  000001.jpg        18
# 2  000002.jpg        80
# 3  000003.jpg        50
# 4  000004.jpg        17
# 5  000005.jpg        27
# 6  000006.jpg        24
# 7  000007.jpg        43
# 8  000008.jpg        26
# 9  000009.jpg        39

# %%
image_arrays.shape
# Out:
# (32, 224, 224, 3)

# %%
image = Image.open(train_gen_flow.filepaths[4])
array = np.array(image)
plt.imshow(array)

# %% [markdown]
# Explain why before submitting

# %%
labels.describe()
# Out:
#           real_age
# count  7591.000000
# mean     31.201159
# std      17.145060
# min       1.000000
# 25%      20.000000
# 50%      29.000000
# 75%      41.000000
# max     100.000000

# %%
labels['real_age'].value_counts()
# Out:
# 30     317
# 25     315
# 27     229
# 26     226
# 28     217
#       ...
# 96       2
# 93       1
# 100      1
# 91       1
# 97       1
# Name: real_age, Length: 97, dtype: int64

# %%
fig, ax = plt.subplots(1, 2, figsize=(10, 4))
sns.histplot(data=labels, x="real_age", kde=True, ax=ax[0])
sns.boxplot(x="real_age", data=labels, ax=ax[1]) 
plt.title("Age distribution")
ax[0].set(xlabel='Age', ylabel='Number of Images')
ax[1].set_xlabel('Age')
plt.show();

# %% [markdown]
# the code snippet uses image.open from the PIL library to open and display an image from a file path, likely representing a sample from the dataset. The image shown is of a person, presumably from a dataset used for age prediction or facial analysis tasks.
#
# The second block involves examining the age labels associated with the images. The labels.describe() function provides a statistical summary of the age labels, showing the count, mean, standard deviation, minimum, and maximum values. This output helps understand the distribution of ages in the dataset, such as the average age and the range of ages.
#
# Next, labels['real_age'].value_counts() displays the frequency of each age in the dataset, highlighting the most common and least common ages. For instance, ages like 27 and 28 appear frequently, while other ages might have fewer occurrences.
#
# Lastly, two plots are presented: a histogram and a boxplot. The histogram shows the distribution of ages in the dataset, illustrating that ages are skewed towards a certain range, with a peak around the mid-20s to early 30s. The boxplot provides a visual summary of the age distribution, showing the median, quartiles, and potential outliers. The dataset appears to have a wide range of ages, with some outliers on the higher end. Overall, these visualizations help in understanding the data distribution and potential preprocessing steps needed for model training.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment </h2>
#
#
# Nice charts 👍
#
#
# </div>
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment  </h2>
#
#
# Since you have two charts, the title was assigned to the second one. Try to use `suptitle` instead.
# </div>

# %%
n_images = 15
rows = 5
columns = n_images/rows

fig = plt.figure(figsize=(10, 10))
image_arrays, age_array = train_gen_flow.next()

for i in range(n_images):
    # add a subplot at the (i+1)th position
    fig.add_subplot(rows, columns, i+1)
    # showing image
    image_file = image_arrays[i]
    age_num = age_array[i]
    plt.imshow(image_file) 
    plt.axis('off')
    plt.title(f"Age: {age_num}")
# Out:
# /tmp/ipykernel_32/2581636183.py:10: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   fig.add_subplot(rows, columns, i+1)

# %% [markdown]
# ### Findings

# %% [markdown]
# Variety of Ages: The images show a range of ages from very young (e.g., Age: 5) to older individuals (e.g., Age: 63). This diversity suggests that the dataset includes a wide age range, which is beneficial for training models that generalize well across different age groups.
#
# Diverse Demographics: The individuals in the images appear to come from various demographic backgrounds, which is valuable for creating a model that is less biased and performs well on a diverse set of users.
#
# Image Quality and Orientation: Some images appear to be tilted or rotated (e.g., Age: 27). This indicates that the dataset may contain variability in terms of image quality, orientation, and possibly lighting conditions. Models trained on this data will need to handle such variances, potentially requiring data augmentation techniques to improve robustness.
#
# Facial Expressions and Poses: The images show different facial expressions and poses. For example, some individuals are smiling (e.g., Age: 40), while others have neutral expressions (e.g., Age: 51). Variations in facial expressions and poses can be challenging for age prediction models, requiring the model to learn to focus on features that are age-relevant rather than expression-relevant.
#
# Potential Dataset Imbalance: Although this visualization only shows 15 images, there seems to be a repeated age category (e.g., Age: 51 appears twice). This might indicate that certain age groups could be more represented than others in the dataset. An imbalanced dataset can lead to models that are biased toward over-represented classes.
#
# Overall, the findings suggest that the dataset has a good diversity in terms of age, demographics, and image conditions, but it might require some preprocessing steps (like rotation correction) and careful handling of potential class imbalances. These factors are crucial for developing a robust age prediction model.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment </h2>
#
#
# Good conclusion.
#
# </div>

# %% [markdown]
# ## Modelling

# %% [markdown]
# Define the necessary functions to train your model on the GPU platform and build a single script containing all of them along with the initialization section.
#
# To make this task easier, you can define them in this notebook and run a ready code in the next section to automatically compose the script.
#
# The definitions below will be checked by project reviewers as well, so that they can understand how you built the model.

# %%
import pandas as pd

import tensorflow as tf

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.resnet import ResNet50
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout, Flatten
from tensorflow.keras.optimizers import Adam

# %%
def load_train(path):
    
    """
    It loads the train part of dataset from path
    """
    
    train_datagen = ImageDataGenerator(validation_split=0.25, 
                                       rescale=1.0/255
                                ) 

    train_gen_flow = train_datagen.flow_from_dataframe(
        dataframe=pd.read_csv(path + "labels.csv"),
        directory=path +'final_files/', 
        x_col='file_name',
        y_col='real_age',
        target_size=(224, 224),
        batch_size=16, # 32
        class_mode='raw',
        subset='training',
        seed=12345
    ) 
    
    return train_gen_flow

# %%
def load_test(path):
    
    """
    It loads the validation/test part of dataset from path
    """
    
    test_datagen = ImageDataGenerator(
        validation_split=0.25, rescale=1.0/255
    )

    test_gen_flow = test_datagen.flow_from_dataframe(
        dataframe=pd.read_csv(path + "labels.csv"),
        directory=path +'final_files/', 
        x_col='file_name',
        y_col='real_age',
        target_size=(224, 224),
        batch_size=16, # 32
        class_mode='raw',
        subset='validation',
        seed=12345
    )
    
    return test_gen_flow

# %%
def create_model(input_shape=(224, 224, 3)):
    
    """
    It defines the model
    """
    
    backbone = ResNet50(
        input_shape=input_shape, #(224, 224, 3), 
        weights='imagenet', 
        include_top=False 
    )

    model = Sequential()
    model.add(backbone)
    model.add(GlobalAveragePooling2D())
    model.add(Dropout(0.5))
    model.add(Dense(1, activation='relu')) 

    model.compile(
        loss='mse', 
        optimizer=Adam(learning_rate=0.0001), # default is 0.001
        metrics=['mae']
    )
    
    print(model.summary())    
    return model

# %%
def train_model(
    model, 
    train_data, 
    test_data, 
    batch_size=None, 
    epochs=20,
    steps_per_epoch=None, 
    validation_steps=None
):

    if steps_per_epoch is None:
        steps_per_epoch = len(train_data)
    if validation_steps is None:
        validation_steps = len(test_data)    
    
    """
    Trains the model given the parameters
    """
    
    model.fit(train_data,
              validation_data=test_data,
              batch_size=batch_size,
              epochs=epochs,
              steps_per_epoch=steps_per_epoch,
              validation_steps=validation_steps,
              verbose=2
    )
    
    return model

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment </h2>
#
#
# Great!
# </div>

# %% [markdown]
# ### Prepare the Script to Run on the GPU Platform

# %% [markdown]
# Given you've defined the necessary functions you can compose a script for the GPU platform, download it via the "File|Open..." menu, and to upload it later for running on the GPU platform.
#
# N.B.: The script should include the initialization section as well. An example of this is shown below.

# %%
# prepare a script to run on the GPU platform

init_str = """
import pandas as pd

import tensorflow as tf

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.resnet import ResNet50
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout, Flatten
from tensorflow.keras.optimizers import Adam
"""

import inspect

with open('run_model_on_gpu.py', 'w') as f:
    
    f.write(init_str)
    f.write('\n\n')
        
    for fn_name in [load_train, load_test, create_model, train_model]:
        
        src = inspect.getsource(fn_name)
        f.write(src)
        f.write('\n\n')

# %% [markdown]
# ### Output

# %% [markdown]
# Epoch 1/20
# 356/356 - 35s - loss: 95.3532 - mae: 7.4339 - val_loss: 124.3362 - val_mae: 8.4921
#
# Epoch 2/20
# 356/356 - 35s - loss: 76.8372 - mae: 6.6707 - val_loss: 127.6357 - val_mae: 8.6035
#
# Epoch 3/20
# 356/356 - 35s - loss: 69.9428 - mae: 6.3992 - val_loss: 91.1531 - val_mae: 7.4454
#
# Epoch 4/20
# 356/356 - 35s - loss: 64.4249 - mae: 6.1407 - val_loss: 124.0287 - val_mae: 8.3481
#
# Epoch 5/20
# 356/356 - 35s - loss: 52.8486 - mae: 5.5913 - val_loss: 109.1004 - val_mae: 8.2192
#
# Epoch 6/20
# 356/356 - 35s - loss: 46.3094 - mae: 5.2223 - val_loss: 85.1038 - val_mae: 7.0332
#
# Epoch 7/20
# 356/356 - 35s - loss: 38.2617 - mae: 4.7951 - val_loss: 92.0900 - val_mae: 7.3359
#
# Epoch 8/20
# 356/356 - 35s - loss: 37.4804 - mae: 4.7402 - val_loss: 80.0016 - val_mae: 6.7239
#
# Epoch 9/20
# 356/356 - 35s - loss: 33.5237 - mae: 4.4271 - val_loss: 83.2579 - val_mae: 6.8529
#
# Epoch 10/20
# 356/356 - 35s - loss: 28.5170 - mae: 4.1411 - val_loss: 83.5056 - val_mae: 6.9629
#
# Epoch 11/20
# 356/356 - 35s - loss: 27.0142 - mae: 3.9700 - val_loss: 92.1290 - val_mae: 7.1866
#
# Epoch 12/20
# 356/356 - 35s - loss: 27.4564 - mae: 4.0428 - val_loss: 185.6307 - val_mae: 11.4591
#
# Epoch 13/20
# 356/356 - 35s - loss: 23.7961 - mae: 3.7407 - val_loss: 92.3429 - val_mae: 7.2467
#
# Epoch 14/20
# 356/356 - 35s - loss: 24.6167 - mae: 3.8116 - val_loss: 92.4542 - val_mae: 7.1401
#
# Epoch 15/20
# 356/356 - 35s - loss: 22.2604 - mae: 3.6746 - val_loss: 82.5822 - val_mae: 6.7841
#
# Epoch 16/20
# 356/356 - 35s - loss: 20.1899 - mae: 3.4430 - val_loss: 86.3830 - val_mae: 6.8304
#
# Epoch 17/20
# 356/356 - 35s - loss: 17.3425 - mae: 3.2205 - val_loss: 78.4369 - val_mae: 6.6419
#
# Epoch 18/20
# 356/356 - 35s - loss: 16.5249 - mae: 3.1295 - val_loss: 81.7731 - val_mae: 6.7226
#
# Epoch 19/20
# 356/356 - 35s - loss: 16.6140 - mae: 3.1421 - val_loss: 80.9727 - val_mae: 6.9908
#
# Epoch 20/20
# 356/356 - 35s - loss: 17.0187 - mae: 3.1785 - val_loss: 93.4115 - val_mae: 7.6512

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2>   Reviewer's comment </h2>
#
#
# You can use Markdown cell for your code and results:
#
#     ```python
#
#     # code
#
#
#     ```
#
# Example:
#
# </div>
#
#
# ```python
#
# import pandas as pd
# from tensorflow.keras.preprocessing.image import ImageDataGenerator
# from tensorflow.keras.applications.resnet import ResNet50
#
#
# ```
#
# </div>

# %% [markdown]
# The script imports necessary libraries, including TensorFlow and Keras for deep learning model development, and pandas for data manipulation. The code appears to create a separate Python file (run_model_on_gpu.py) and dynamically writes the content of several functions (load_train, load_test, create_model, train_model) into this file. This approach allows for better management of the code execution environment, especially when dealing with GPU resources.
#
# The output section shows the training progress of a deep learning model over 20 epochs, where each epoch displays values for loss, mean absolute error (MAE), validation loss, validation MAE, and validation accuracy (val_mae). The training results indicate a steady decrease in both loss and MAE over the epochs, demonstrating that the model is learning and improving its performance on the training data. The validation metrics (val_loss and val_mae), however, exhibit a more fluctuating pattern. While they generally decrease, there are some epochs where these values increase slightly, suggesting that the model may be experiencing slight overfitting or that the validation data is more challenging. By the end of the training, the loss and MAE values are relatively low, indicating good model convergence, but the difference between training and validation performance hints at the need for further tuning, such as regularization or a more complex model architecture, to enhance generalization to unseen data. Overall, the code and results show a well-structured deep learning workflow with promising, albeit improvable, model performance.

# %% [markdown]
# ## Conclusions

# %% [markdown]
# Data Loading and Preparation:
#
# The dataset was loaded, preprocessed, and prepared for analysis. The images were converted to a suitable format, and their corresponding labels (ages) were associated for training purposes.
# Exploratory Data Analysis (EDA):
#
# EDA was conducted to understand the distribution of the age data. The age data was visualized using histograms and box plots to identify any potential skewness, outliers, or patterns within the data. The data shows a relatively normal distribution with a few outliers, indicating a wide range of ages.
# Model Development:
#
# The model was trained using a convolutional neural network (CNN) approach, leveraging Keras and TensorFlow libraries. The model aimed to predict the age of an individual based on image features extracted from the provided datasets.
# Model Evaluation:
#
# The evaluation was conducted to assess the accuracy of the model across different age groups. The predicted ages were compared to the actual ages, and the model's performance was visually inspected to understand how well it generalized across the dataset. It was observed that while the model performed reasonably well in predicting the general age group, there were instances of significant deviations.
# Findings:
#
# The model demonstrated varying levels of accuracy across different age groups. It tended to perform better on middle-aged individuals (30-50 range) but struggled with more extreme ages (very young or very old). This suggests that the model could benefit from more data representing these age ranges or more sophisticated modeling techniques to better capture the features relevant to those groups.
# Challenges and Recommendations:
#
# A notable challenge was the model's difficulty in distinguishing subtle age differences within a narrow range (e.g., between 20 and 25 years). Future work could include refining the model architecture, incorporating additional data preprocessing techniques, or exploring alternative models like transfer learning from pre-trained networks to improve performance.
# Overall, the analysis demonstrated a solid approach to solving an age prediction problem using deep learning techniques, with meaningful insights into model strengths and areas for improvement. Future efforts should focus on enhancing model robustness, particularly for less-represented age groups, to achieve better generalization and accuracy

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment </h2>
#
#
# Great conclusion! What else can be done? Sometimes it may be helpful to try different data augmentation approaches. By the way, here's a good library [albumentations](https://github.com/albumentations-team/albumentations). Apart from this, we can consider introducing additional layers with some normalization methods. The optimization part is good. Adam is quite flexible, but you can still try other optimizers if you want. For example, AdamW sometimes shows better results.
#
#
#
# Regarding age verification, I would argue that we have some noticable limits here. It is much more reliable and much easier to just compare the id or passport photo to the customer's face.
#
# </div>

# %% [markdown]
# # Checklist

# %% [markdown]
# - [ ]  Notebook was opened
# - [ ]  The code is error free
# - [ ]  The cells with code have been arranged by order of execution
# - [ ]  The exploratory data analysis has been performed
# - [ ]  The results of the exploratory data analysis are presented in the final notebook
# - [ ]  The model's MAE score is not higher than 8
# - [ ]  The model training code has been copied to the final notebook
# - [ ]  The model training output has been copied to the final notebook
# - [ ]  The findings have been provided based on the results of the model training
